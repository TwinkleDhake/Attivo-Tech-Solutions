# %%
import pandas as pd

# %%
nsd = pd.read_csv(r"C:\Users\yasha\Desktop\AI_ML\AI_ML_DailyPractice\Day5_3_07_2025\Nasdaq Stocks Data\dividend_stocks_only.csv")

# %%
nsd.head()
# Out:
#   symbol                                      security_name listing_exchange  \
# 0      A            Agilent Technologies, Inc. Common Stock                N
# 1    AAL       American Airlines Group, Inc. - Common Stock                Q
# 2    AAP  Advance Auto Parts Inc Advance Auto Parts Inc W/I                N
# 3   AAPL                          Apple Inc. - Common Stock                Q
# 4    AAT           American Assets Trust, Inc. Common Stock                N
#
#   etf financial_status    zip             sector  fullTimeEmployees  \
# 0   N              NaN  95051         Healthcare            16300.0
# 1   N                N  76155        Industrials           131500.0
# 2   N              NaN  27604  Consumer Cyclical            39000.0
# 3   N                N  95014         Technology           137000.0
# 4   N              NaN  92130        Real Estate              205.0
#
#           city state  ... enterpriseToRevenue forwardEps  \
# ...

# %%
nsd.isnull().sum()
# Out:
# symbol                            0
# security_name                     0
# listing_exchange                  0
# etf                               0
# financial_status               1305
# zip                              20
# sector                           13
# fullTimeEmployees               569
# city                              2
# state                           157
# country                           0
# industry                         13
# twoHundredDayAverage              0
# trailingAnnualDividendYield     170
# averageDailyVolume10Day           0
# regularMarketPreviousClose        0
# open                              0
# averageVolume10days               0
# dividendRate                      0
# regularMarketVolume               0
# marketCap                        17
# averageVolume                     0
# dayLow                            0
# ask                               0
# fiftyTwoWeekHigh                  0
# forwardPE                       588
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
threshold = 0.3

# %%
#nsd.dropna(inplace=True)

# %%
nsd = nsd.loc[:, nsd.isnull().mean() < threshold]

# %%
num_cols = nsd.select_dtypes(include=['float64', 'int64']).columns

# %%
nsd[num_cols] = nsd[num_cols].fillna(nsd[num_cols].median())

# %%
cat_cols = nsd.select_dtypes(include=['object']).columns

# %%
nsd[cat_cols] = nsd[cat_cols].fillna('Unknown')

# %%
dummy_columns = ["symbol", "security_name", "zip", "listing_exchange", "etf", "financial_status", "zip", "sector", "city", "state", "revenueQuarterlyGrowth", "floatShares", "enterpriseValue", "country", "industry"]

# %%
dummy_cols = [col for col in dummy_columns if col in nsd.columns]

# %%
nsd = pd.get_dummies(nsd, columns=dummy_cols, drop_first=True)

# %%
def categorize_dividend(value):
    if value == 0:
        return "No"
    elif value <= 0.5:
        return "Low"
    elif value <= 2:
        return "Medium"
    else:
        return "High"
nsd['dividend_category'] = nsd['latest_dividend'].apply(categorize_dividend)

# %%
X = nsd.drop(['latest_dividend', 'dividend_category'], axis=1)

# %%
X.head()
# Out:
#    fullTimeEmployees  twoHundredDayAverage  trailingAnnualDividendYield  \
# 0            16300.0              79.98419                     0.007802
# 1           131500.0              20.70919                     0.035907
# 2            39000.0             133.39670                     0.001770
# 3           137000.0             286.99980                     0.009724
# 4              205.0              37.83544                     0.042963
#
#    averageDailyVolume10Day  regularMarketPreviousClose    open  \
# 0                  2807514                       86.13   86.30
# 1                 66709542                       11.14   12.43
# 2                  1514942                      135.58  137.50
# 3                 27552328                      316.73  316.14
# 4                   349871                       27.00   28.01
#
#    averageVolume10days  dividendRate  regularMarketVolume     marketCap  ...  \
# ...

# %%
y = nsd['dividend_category']

# %%
y.head()
# Out:
# 0       Low
# 1       Low
# 2       Low
# 3    Medium
# 4       Low
# Name: dividend_category, dtype: object

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 5)

# %%
X_train.shape
# Out:
# (1551, 10384)

# %%
X_test.shape
# Out:
# (388, 10384)

# %%
y_test.shape
# Out:
# (388,)

# %%
y_train.shape
# Out:
# (1551,)

# %%
from sklearn.linear_model import LogisticRegression

# %%
log_reg = LogisticRegression(max_iter=1000)

# %%
log_reg.fit(X_train, y_train)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:470: ConvergenceWarning: lbfgs failed to converge after 1000 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=1000).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(max_iter=1000)

# %%
y_pred = log_reg.predict(X_test)
