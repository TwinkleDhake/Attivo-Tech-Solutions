# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = [12, 7, 3, 19, 21, 22, 25, 18, 5, 14, 22, 31, 3, 8, 11, 19, 100, -25, 80]

# %%
plt.boxplot(data)
plt.title("Box plot example")
plt.ylabel("Values")
plt.show()
