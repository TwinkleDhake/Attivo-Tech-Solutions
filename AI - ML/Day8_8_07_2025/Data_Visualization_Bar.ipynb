# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#pip install seaborn

# %%
categories = ['O', 'A', 'B', 'AB']
population = [45, 30, 30, 50]

# %%
plt.bar(categories, population, color= 'red', edgecolor = 'black')
plt.title("Blood Group Count")
plt.xlabel("Blood Groups")
plt.ylabel("Count")
plt.grid(axis = 'y')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
