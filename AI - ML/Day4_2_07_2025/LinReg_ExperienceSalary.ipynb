# %%
import pandas as pd

# %%
exp_sal = pd.read_csv(r'C:\Users\yasha\Desktop\AI_ML\AI_ML_DailyPractice\Day4_2_07_2025\Linear_Regression_Experience-Salary\Experience-Salary.csv')

# %%
exp_sal.head()
# Out:
#    exp(in months)  salary(in thousands)
# 0       18.290293             16.521825
# 1       17.023407             11.666234
# 2       26.343613             23.167255
# 3       19.105834             20.877145
# 4       27.742516             23.166236

# %%
exp_sal.tail()
# Out:
#      exp(in months)  salary(in thousands)
# 995       22.161741             24.666502
# 996       32.266497             24.160270
# 997       17.039030             19.903797
# 998       25.222124             21.974413
# 999       16.418028             19.634787

# %%
exp_sal.shape
# Out:
# (1000, 2)

# %%
exp_sal.describe()
# Out:
#        exp(in months)  salary(in thousands)
# count     1000.000000           1000.000000
# mean        26.157825             26.722597
# std          8.717091              8.844761
# min          0.697594             -1.276342
# 25%         20.073600             20.531008
# 50%         25.875225             26.745576
# 75%         32.406986             32.615753
# max         49.463222             55.297016

# %%
exp_sal.isnull().sum()
# Out:
# exp(in months)          0
# salary(in thousands)    0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X = exp_sal[["exp(in months)"]]

# %%
X.head()
# Out:
#    exp(in months)
# 0       18.290293
# 1       17.023407
# 2       26.343613
# 3       19.105834
# 4       27.742516

# %%
y = exp_sal["salary(in thousands)"]

# %%
y.head()
# Out:
# 0    16.521825
# 1    11.666234
# 2    23.167255
# 3    20.877145
# 4    23.166236
# Name: salary(in thousands), dtype: float64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 5)

# %%
X_train.shape
# Out:
# (800, 1)

# %%
X_train = X_train.values.reshape(-1, 1)

# %%
X_test = X_test.values.reshape(-1, 1)

# %%
y_test.shape
# Out:
# (200,)

# %%
from sklearn.linear_model import LinearRegression

# %%
lin_reg = LinearRegression()

# %%
lin_reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
ypred = lin_reg.predict(X_test)

# %%
prediction = lin_reg.predict([[10]])

# %%
print("Predicted salary for 10 months experience:", prediction)
# Out:
# Predicted salary for 10 months experience: [13.48655585]
