# %%
import pandas as pd

# %%
energy_con = pd.read_csv(r'C:\Users\yasha\Desktop\AI_ML\AI_ML_DailyPractice\Day4_2_07_2025\Multiple_Linear_Reg-Energy-Cosumption-Dataset\train_energy_data.csv')

# %%
energy_con.head()
# Out:
#   Building Type  Square Footage  Number of Occupants  Appliances Used  \
# 0   Residential            7063                   76               10
# 1    Commercial           44372                   66               45
# 2    Industrial           19255                   37               17
# 3   Residential           13265                   14               41
# 4    Commercial           13375                   26               18
#
#    Average Temperature Day of Week  Energy Consumption
# 0                29.84     Weekday             2713.95
# 1                16.72     Weekday             5744.99
# 2                14.30     Weekend             4101.24
# 3                32.82     Weekday             3009.14
# 4                11.92     Weekday             3279.17

# %%
energy_con.tail()
# Out:
#     Building Type  Square Footage  Number of Occupants  Appliances Used  \
# 995   Residential           14419                   68               44
# 996    Industrial           12194                    7               22
# 997    Commercial           39562                   88               20
# 998   Residential            8348                   67               37
# 999    Commercial           15813                   57               11
#
#      Average Temperature Day of Week  Energy Consumption
# 995                23.95     Weekend             3661.21
# 996                14.67     Weekend             3546.34
# 997                32.18     Weekday             5147.21
# 998                16.48     Weekend             3244.98
# 999                31.40     Weekend             3423.63

# %%
energy_con.shape
# Out:
# (1000, 7)

# %%
energy_con.describe()
# Out:
#        Square Footage  Number of Occupants  Appliances Used  \
# count        1000.000          1000.000000      1000.000000
# mean        25462.388            48.372000        25.606000
# std         14294.554            29.061972        14.105166
# min           560.000             1.000000         1.000000
# 25%         13169.750            22.000000        13.000000
# 50%         25477.000            47.000000        26.000000
# 75%         37446.250            73.250000        38.000000
# max         49997.000            99.000000        49.000000
#
#        Average Temperature  Energy Consumption
# count          1000.000000         1000.000000
# mean             22.611390         4166.252570
# std               7.139943          933.313064
# min              10.050000         1683.950000
# 25%              16.475000         3509.482500
# 50%              22.815000         4175.730000
# 75%              28.850000         4863.850000
# ...

# %%
energy_con.isnull().sum()
# Out:
# Building Type          0
# Square Footage         0
# Number of Occupants    0
# Appliances Used        0
# Average Temperature    0
# Day of Week            0
# Energy Consumption     0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
energy_con = pd.get_dummies(energy_con, columns=["Building Type", "Day of Week"], drop_first=True)

# %%
"""col_to_encode = ["Building Type", "Day of Week"]
for columns in col_to_encode:
    energy_con[columns] = le.fit_transform(energy_con[columns])
    energy_con.head()"""
# Out:
# 'col_to_encode = ["Building Type", "Day of Week"]\nfor columns in col_to_encode:\n    energy_con[columns] = le.fit_transform(energy_con[columns])\n    energy_con.head()'

# %%
X = energy_con.drop("Energy Consumption", axis = 'columns')

# %%
X.head()
# Out:
#    Square Footage  Number of Occupants  Appliances Used  Average Temperature  \
# 0            7063                   76               10                29.84
# 1           44372                   66               45                16.72
# 2           19255                   37               17                14.30
# 3           13265                   14               41                32.82
# 4           13375                   26               18                11.92
#
#    Building Type_Industrial  Building Type_Residential  Day of Week_Weekend
# 0                     False                       True                False
# 1                     False                      False                False
# 2                      True                      False                 True
# 3                     False                       True                False
# 4                     False                      False                False

# %%
y = energy_con['Energy Consumption']

# %%
y.head()
# Out:
# 0    2713.95
# 1    5744.99
# 2    4101.24
# 3    3009.14
# 4    3279.17
# Name: Energy Consumption, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 5)

# %%
X_train.shape
# Out:
# (700, 7)

# %%
y_test.shape
# Out:
# (300,)

# %%
from sklearn.linear_model import LinearRegression

# %%
lin_reg = LinearRegression()

# %%
lin_reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lin_reg.predict(X_test)
