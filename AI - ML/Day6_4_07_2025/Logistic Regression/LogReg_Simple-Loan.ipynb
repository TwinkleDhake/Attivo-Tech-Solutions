# %%
import pandas as pd

# %%
la = pd.read_csv(r"C:\Users\yasha\Desktop\AI_ML\AI_ML_DailyPractice\Day6_4_07_2025\Logistic Regression\Classification\Simple Loan\loan.csv")

# %%
la.head()
# Out:
#    age  gender  occupation education_level marital_status  income  \
# 0   32    Male    Engineer      Bachelor's        Married   85000
# 1   45  Female     Teacher        Master's         Single   62000
# 2   28    Male     Student     High School         Single   25000
# 3   51  Female     Manager      Bachelor's        Married  105000
# 4   36    Male  Accountant      Bachelor's        Married   75000
#
#    credit_score loan_status
# 0           720    Approved
# 1           680    Approved
# 2           590      Denied
# 3           780    Approved
# 4           710    Approved

# %%
la.isnull().sum()
# Out:
# age                0
# gender             0
# occupation         0
# education_level    0
# marital_status     0
# income             0
# credit_score       0
# loan_status        0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
la.dropna(inplace=True)

# %%
la = pd.get_dummies(la, columns=["gender", "occupation", "education_level",	"marital_status"], drop_first=True)

# %%
X = la.drop("loan_status", axis = 'columns')

# %%
X.head()
# Out:
#    age  income  credit_score  gender_Male  occupation_Analyst  \
# 0   32   85000           720         True               False
# 1   45   62000           680        False               False
# 2   28   25000           590         True               False
# 3   51  105000           780        False               False
# 4   36   75000           710         True               False
#
#    occupation_Architect  occupation_Artist  occupation_Banker  \
# 0                 False              False              False
# 1                 False              False              False
# 2                 False              False              False
# 3                 False              False              False
# 4                 False              False              False
#
#    occupation_Chef  occupation_Consultant  ...  occupation_Student  \
# 0            False                  False  ...               False
# 1            False                  False  ...               False
# ...

# %%
y = la["loan_status"]

# %%
y.head()
# Out:
# 0    Approved
# 1    Approved
# 2      Denied
# 3    Approved
# 4    Approved
# Name: loan_status, dtype: object

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 5)

# %%
X_train.shape
# Out:
# (48, 46)

# %%
X_test.shape
# Out:
# (13, 46)

# %%
y_test.shape
# Out:
# (13,)

# %%
y_train.shape
# Out:
# (48,)

# %%
from sklearn.linear_model import LogisticRegression

# %%
log_reg = LogisticRegression(max_iter=1000)

# %%
log_reg.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
y_pred = log_reg.predict(X_test)
