# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\yasha\Desktop\AI_ML\AI_ML_DailyPractice\Day6_4_07_2025\Decision Tree\Classification\Avocado Ripeness\avocado_ripeness_dataset.csv')

# %%
df.head()
# Out:
#    firmness  hue  saturation  brightness color_category  sound_db  weight_g  \
# 0      14.5   19          40          26          black        34       175
# 1      71.7   53          69          75          green        69       206
# 2      88.5   60          94          46     dark green        79       220
# 3      93.8  105          87          41     dark green        75       299
# 4      42.5  303          58          32         purple        63       200
#
#    size_cm3         ripeness
# 0       261             ripe
# 1       185  pre-conditioned
# 2       143             hard
# 3       140             hard
# 4       227         breaking

# %%
df.isnull().sum()
# Out:
# firmness          0
# hue               0
# saturation        0
# brightness        0
# color_category    0
# sound_db          0
# weight_g          0
# size_cm3          0
# ripeness          0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
col_to_encode = ["color_category", "ripeness"]

# %%
for columns in col_to_encode:
    df[columns] = le.fit_transform(df[columns])
    df.head()

# %%
X = df.drop(['sound_db', 'size_cm3', 'ripeness'], axis = 'columns')

# %%
#X = df.name

# %%
X.head()
# Out:
#    firmness  hue  saturation  brightness  color_category  weight_g
# 0      14.5   19          40          26               0       175
# 1      71.7   53          69          75               2       206
# 2      88.5   60          94          46               1       220
# 3      93.8  105          87          41               1       299
# 4      42.5  303          58          32               3       200

# %%
y = df['ripeness']

# %%
y.head()
# Out:
# 0    4
# 1    3
# 2    2
# 3    2
# 4    0
# Name: ripeness, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test, = train_test_split(X, y, test_size = 0.3, random_state = 3)

# %%
X_train.shape
# Out:
# (175, 6)

# %%
y_test.shape
# Out:
# (75,)

# %%
from sklearn.tree import DecisionTreeClassifier, plot_tree

# %%
clf = DecisionTreeClassifier(random_state = 2)

# %%
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=2)

# %%
y_pred = clf.predict(X_test)

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(100,100))
plot_tree(clf,feature_names = X.columns, filled = True)
# Out:
# [Text(0.2857142857142857, 0.9, 'firmness <= 20.1\ngini = 0.799\nsamples = 175\nvalue = [34, 36, 30, 36, 39]'),
#  Text(0.14285714285714285, 0.7, 'gini = 0.0\nsamples = 39\nvalue = [0, 0, 0, 0, 39]'),
#  Text(0.21428571428571427, 0.8, 'True  '),
#  Text(0.42857142857142855, 0.7, 'firmness <= 39.4\ngini = 0.749\nsamples = 136\nvalue = [34, 36, 30, 36, 0]'),
#  Text(0.3571428571428571, 0.8, '  False'),
#  Text(0.2857142857142857, 0.5, 'gini = 0.0\nsamples = 36\nvalue = [0, 36, 0, 0, 0]'),
#  Text(0.5714285714285714, 0.5, 'firmness <= 59.85\ngini = 0.665\nsamples = 100\nvalue = [34, 0, 30, 36, 0]'),
#  Text(0.42857142857142855, 0.3, 'gini = 0.0\nsamples = 34\nvalue = [34, 0, 0, 0, 0]'),
#  Text(0.7142857142857143, 0.3, 'color_category <= 1.5\ngini = 0.496\nsamples = 66\nvalue = [0, 0, 30, 36, 0]'),
#  Text(0.5714285714285714, 0.1, 'gini = 0.0\nsamples = 30\nvalue = [0, 0, 30, 0, 0]'),
#  Text(0.8571428571428571, 0.1, 'gini = 0.0\nsamples = 36\nvalue = [0, 0, 0, 36, 0]')]
